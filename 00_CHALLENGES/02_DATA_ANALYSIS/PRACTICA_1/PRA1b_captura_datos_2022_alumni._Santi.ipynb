# %% [markdown]
# # Práctica 1b: INTRODUCCIÓN A LOS DATOS

# %% [markdown]
# En esta práctica vamos a retomar el contacto con los datos y vamos a hacer un repaso con los formatos de datos más habituales.

# %% [markdown]
# **NOTA:**  Para cargar los ficheros de datos se recomienda que se guarden en la carpeta del google drive donde se está trabajando.
#
# Una vez guardados, se debe montar la unidad del drive para poder acceder y referenciar la ruta para cargar los datos.
#
# El código que permite cargar la unidad drive es:
#
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
#
# ```

# %% [markdown]
# _Ejemplo:_

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH="/content/drive/My Drive/......./PRA1/data/"

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# ```
# {'\ufeff92086009452':
#
#   {'register_id': '\ufeff92086009452',
#   'name': 'Mercat de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '33049',
#   'modified': '44768,41858',
#   ...
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}
#   },
# …
#
# ```

# %% [markdown]
# **Por tanto, los pasos a realizar en este ejercicio son:**
#
# - **Cargar los csv y visualizar la forma y las columnas que tienen.**
#
# - **Crear un diccionario a partir del dataframe relativo a los mercados(dict_mercados). Las claves de este diccionario debe ser el campo ‘register_id’. Los valores del diccionario serán a su vez otro diccionario donde las claves sean el resto de campos y los valores el valor que adquiere cada campo en cada mercado.**
#
# - **Crear un diccionario a partir del dataframe relativo al padron (dict_padro). Las claves de este diccionario debe ser el campo ‘Nom_Barri’. Los valores del diccionario serán a su vez otro diccionario donde las claves sean [`Dones', 'Homes' y 'Total]` y los valores el valor calculado que adquiere cada campo.**
#
# - **Crear un diccionario que sea la combinación de los dos anteriores (dict_completo). Este diccionario debe crearse añadiendo un campo nuevo a la información relativa a cada mercado del diccionario dict_mercados. Este nuevo campo se llamará ‘padro_barri’ y su valor será la información relativa al padrón que se corresponde con su barrio. En los casos donde no exista valor de padrón, asignar el valor  de ‘NA’.**
#
# - **Visualizar el diccionario resultante. ¿Cuántos registros tiene? ¿Coincide este valor con el número de instancias del dataframe df_mercados?**
#
# - **Con el diccionario resultante, responder a las siguientes preguntas accediendo a los valores del diccionario que responden a las mismas:**
#  - **¿Cuántas mujeres hay en el barrio que está el mercado con register_id=92086009450**
#  - **¿En qué calle esta el mercado cuyo register_id=﻿92086009457?**
#
#
# - **Guardar el diccionario en un fichero con formato .json.**

# %% [markdown]
# NOTA: Para la construcción del diccionario dict_completo, se recomienda que se genere un bucle donde en cada iteración se evalúe cada mercado de dict_mercados y se consulte si hay información del padron para el barrio donde está ubicado. En caso afirmativo añadir los datos indicados, en caso contrario, añadir el valor ‘NA’ al campo padro.

# %%
# Cargar csv y visualitzar la forma y les columnes

import pandas as pd
pd.options.display.max_colwidth = None
df_mercados = pd.read_csv('C:/Users/Santiago/Desktop/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/00_CHALLENGES/99_datasets/merdados_.csv',sep=';')
df_mercados
# Out:
#      register_id                                    name  institution_id  \
# 0   ﻿92086009449                  Mercat de La Concepció             NaN
# 1   ﻿92086009449                  Mercat de La Concepció             NaN
# 2   ﻿92086009450            Mercat de la Sagrada Família             NaN
# 3   ﻿92086009452                   Mercat de Sant Antoni             NaN
# 4   ﻿92086009457                     Mercat de Les Corts             NaN
# 5   ﻿92086009457                     Mercat de Les Corts             NaN
# 6   ﻿92086009773                  Mercat de la Llibertat             NaN
# 7   ﻿92086009781                    Mercat de Montserrat             NaN
# 8   ﻿92086009789                    Mercat de Sant Martí             NaN
# 9   ﻿92086009790                        Mercat del Besòs             NaN
# 10  ﻿92086009451                        Mercat del Ninot             NaN
# 11  ﻿92086009775                       Mercat del Carmel             NaN
# 12  ﻿92086009783                   Mercat de La Trinitat             NaN
# 13  ﻿92086009783                   Mercat de La Trinitat             NaN
# 14  ﻿92086009785                      Mercat de Felip II             NaN
# 15  ﻿92086009459                        Mercat de Sarrià             NaN
# 16  ﻿92086009459                        Mercat de Sarrià             NaN
# 17  ﻿92086009463            Mercat de l'Abaceria Central             NaN
# 18  ﻿92086019717                     Mercat de Canyelles             NaN
# 19  ﻿92086009782              Mercat de Ciutat Meridiana             NaN
# 20  ﻿92086009787                   Mercat de Sant Andreu             NaN
# 21  ﻿92086009458                       Mercat de Galvany             NaN
# 22  ﻿92086009460               Mercat de Les Tres Torres             NaN
# 23  ﻿92086009462                  Mercat de Sant Gervasi             NaN
# 24  ﻿92086009468  Mercat Encants Vells Fira de Bellcaire             NaN
# 25  ﻿92086009468  Mercat Encants Vells Fira de Bellcaire             NaN
# 26  ﻿92086009464                       Mercat de Lesseps             NaN
# 27  ﻿92086009467           Mercat Encants de Sant Antoni             NaN
# 28  ﻿92086009467           Mercat Encants de Sant Antoni             NaN
# 29  ﻿92086009447      Mercat de Sant Josep - La Boqueria             NaN
# 30  ﻿92086009448                Mercat de Santa Caterina             NaN
# 31  ﻿92086009454                    Mercat d'Hostafrancs             NaN
# 32  ﻿92086009455                         Mercat de Sants             NaN
# 33  ﻿92086009456                     Mercat de La Marina             NaN
# 34  ﻿92086011624        Mercat de les Flors *Les Rambles             NaN
# 35  ﻿92086011624        Mercat de les Flors *Les Rambles             NaN
# 36  ﻿96058202955         Mercat Dominical de Sant Antoni             NaN
# 37  ﻿96058202955         Mercat Dominical de Sant Antoni             NaN
# 38  ﻿92086009445                Mercat de La Barceloneta             NaN
# 39  ﻿92086009776                     Mercat del Guinardó             NaN
# 40  ﻿92086009779                  Mercat de La Guineueta             NaN
# 41  ﻿92086009788                         Mercat del Clot             NaN
# 42  ﻿92086009791                     Mercat del Poblenou             NaN
# 43  ﻿92086009793                    Mercat de Provençals             NaN
# 44  ﻿92086009774                    Mercat de l'Estrella             NaN
# 45  ﻿92086009777       Mercat de Vall d'Hebron -Taxonera             NaN
# 46  ﻿92086009778                          Mercat d'Horta             NaN
# 47  ﻿92086009780                      Mercat de La Mercè             NaN
# 48  ﻿92086009784                   Mercat del Bon Pastor             NaN
# 49  ﻿99400069155                   Mercat del Fort Pienc             NaN
# 50  ﻿99400695137                         Mercat de Núria             NaN
#
#     institution_name      created     modified  addresses_roadtype_id  \
# 0                NaN        31044  44732,38445                    NaN
# 1                NaN        31044  44732,38445                    NaN
# 2                NaN        31044  44728,48622                    NaN
# 3                NaN        33049  44768,41858                    NaN
# 4                NaN        31044  44732,38082                    NaN
# 5                NaN        31044  44732,38082                    NaN
# 6                NaN        31064  44732,37875                    NaN
# 7                NaN        31064  44728,48757                    NaN
# 8                NaN        31064  44768,43696                    NaN
# 9                NaN        31064  44818,36006                    NaN
# 10               NaN        31044  44757,58065                    NaN
# 11               NaN        31064  44728,49168                    NaN
# 12               NaN        31064  44728,48686                    NaN
# 13               NaN        31064  44728,48686                    NaN
# 14               NaN        31064  44728,48279                    NaN
# 15               NaN        31044  44728,49005                    NaN
# 16               NaN        31044  44728,49005                    NaN
# 17               NaN        31044   44757,5772                    NaN
# 18               NaN        31862  44728,48193                    NaN
# 19               NaN        31064  44728,48264                    NaN
# 20               NaN        31064  44819,56347                    NaN
# 21               NaN        31044  44728,48292                    NaN
# 22               NaN        31044  44728,48724                    NaN
# 23               NaN        31044  44732,38267                    NaN
# 24               NaN        31044  44757,57901                    NaN
# 25               NaN        31044  44757,57901                    NaN
# 26               NaN        31044  44732,37627                    NaN
# 27               NaN        31044  44770,57452                    NaN
# 28               NaN        31044  44770,57452                    NaN
# 29               NaN        31044  44757,57829                    NaN
# 30               NaN        31044  44757,58194                    NaN
# 31               NaN        31044   44728,4821                    NaN
# 32               NaN        31044  44768,41922                    NaN
# 33               NaN        31044  44732,39465                    NaN
# 34               NaN        31128  44727,41879                    NaN
# 35               NaN        31128  44727,41879                    NaN
# 36               NaN        35122   44755,4564                    NaN
# 37               NaN        35122   44755,4564                    NaN
# 38               NaN        31044  44825,41282                    NaN
# 39               NaN        31064  44768,42299                    NaN
# 40               NaN        31064  44776,56573                    NaN
# 41               NaN        31064   44768,4115                    NaN
# 42               NaN        31064  44728,49295                    NaN
# 43               NaN        31064  44768,43597                    NaN
# 44               NaN        31064   44753,5782                    NaN
# 45               NaN        31064  44824,42722                    NaN
# 46               NaN        31064  44824,42873                    NaN
# 47               NaN        31064  44771,46113                    NaN
# 48               NaN        31064  44728,49155                    NaN
# 49               NaN  37958,58828  44732,38674                    NaN
# 50               NaN   44754,5899  44760,37418                    NaN
#
#     addresses_roadtype_name  addresses_road_id  \
# 0                       NaN              18505
# 1                       NaN              18505
# 2                       NaN             238400
# 3                       NaN             349706
# 4                       NaN             343903
# 5                       NaN             343903
# 6                       NaN             179107
# 7                       NaN             120807
# 8                       NaN             270107
# 9                       NaN             165601
# 10                      NaN             191204
# 11                      NaN             185700
# 12                      NaN             250507
# 13                      NaN             250507
# 14                      NaN             121402
# 15                      NaN             278007
# 16                      NaN             278007
# 17                      NaN             305100
# 18                      NaN              18254
# 19                      NaN              92950
# 20                      NaN             208307
# 21                      NaN             318804
# 22                      NaN             357103
# 23                      NaN             231706
# 24                      NaN              73900
# 25                      NaN              73900
# 26                      NaN             356803
# 27                      NaN             349706
# 28                      NaN             349706
# 29                      NaN              34308
# 30                      NaN             132952
# 31                      NaN              94809
# 32                      NaN             304209
# 33                      NaN             369408
# 34                      NaN              34308
# 35                      NaN              34308
# 36                      NaN             349706
# 37                      NaN             349706
# 38                      NaN             260908
# 39                      NaN             334403
# 40                      NaN             351901
# 41                      NaN             209004
# 42                      NaN             349003
# 43                      NaN             208205
# 44                      NaN             144306
# 45                      NaN             352507
# 46                      NaN             329505
# 47                      NaN             119003
# 48                      NaN             295709
# 49                      NaN             701420
# 50                      NaN             275600
#
#                addresses_road_name  ...     values_description  \
# 0                   Carrer d'Aragó  ...                    NaN
# 1                   Carrer d'Aragó  ...                    NaN
# 2                Carrer de Padilla  ...                    NaN
# 3        Carrer del Comte d'Urgell  ...                    NaN
# 4          Travessera de les Corts  ...                    NaN
# 5          Travessera de les Corts  ...                    NaN
# 6            Plaça de la Llibertat  ...                    NaN
# 7                     Via Favència  ...                    NaN
# 8              Carrer de Puigcerdà  ...                    NaN
# 9                   C Jaume Huguet  ...                    NaN
# 10              Carrer de Mallorca  ...                    NaN
# 11                     C Llobregós  ...                    NaN
# 12            Carrer de la Pedrosa  ...                    NaN
# 13            Carrer de la Pedrosa  ...                    NaN
# 14              Carrer de Felip II  ...                    NaN
# 15      Pg Reina Elisenda Montcada  ...                    NaN
# 16      Pg Reina Elisenda Montcada  ...                    NaN
# 17                    Pg Sant Joan  ...                    NaN
# 18        Carrer d'Antonio Machado  ...                    NaN
# 19             Carrer de Costabona  ...                    NaN
# 20              Plaça del Mercadal  ...                    NaN
# 21               Carrer de Santaló  ...                    NaN
# 22              Carrer dels Vergós  ...                    NaN
# 23             Pl Joaquim Folguera  ...                    NaN
# 24       Carrer de los Castillejos  ...                    NaN
# 25       Carrer de los Castillejos  ...                    NaN
# 26                 Carrer de Verdi  ...                    NaN
# 27                C Comte d'Urgell  ...                    NaN
# 28                C Comte d'Urgell  ...                    NaN
# 29                Carrer la Rambla  ...             Informació
# 30               Av Francesc Cambó  ...                    NaN
# 31       Carrer de la Creu Coberta  ...                    NaN
# 32                    C Sant Jordi  ...                    NaN
# 33       Passeig de la Zona Franca  ...                    NaN
# 34                     C la Rambla  ...                    NaN
# 35                     C la Rambla  ...                    NaN
# 36                C Comte d'Urgell  ...  Mercat de Sant Antoni
# 37                C Comte d'Urgell  ...  Mercat de Sant Antoni
# 38           Plaça del Poeta Boscà  ...                    NaN
# 39               C Teodor Llorente  ...                    NaN
# 40            Passeig de Valldaura  ...                    NaN
# 41                       Pl Mercat  ...                    NaN
# 42                         Pl Unió  ...                    NaN
# 43               Carrer de Menorca  ...                    NaN
# 44          Carrer de Pi i Margall  ...                    NaN
# 45                Pg Vall d'Hebron  ...                    NaN
# 46                 Carrer del Tajo  ...                    NaN
# 47         Passeig de Fabra i Puig  ...                    NaN
# 48                    C Sant Adrià  ...                    NaN
# 49                   Pl Fort Pienc  ...                    NaN
# 50  Avinguda dels Rasos de Peguera  ...                    NaN
#
#     secondary_filters_id     secondary_filters_name  \
# 0               66731068                   WiFi BCN
# 1               58731068         Mercats municipals
# 2               58731068         Mercats municipals
# 3               58731068         Mercats municipals
# 4               66731068                   WiFi BCN
# 5               58731068         Mercats municipals
# 6               58731068         Mercats municipals
# 7               58731068         Mercats municipals
# 8               58731068         Mercats municipals
# 9               58731068         Mercats municipals
# 10              58731068         Mercats municipals
# 11              58731068         Mercats municipals
# 12              66731068                   WiFi BCN
# 13              58731068         Mercats municipals
# 14              58731068         Mercats municipals
# 15              66731068                   WiFi BCN
# 16              58731068         Mercats municipals
# 17              58731068         Mercats municipals
# 18              58731068         Mercats municipals
# 19              58731068         Mercats municipals
# 20              58731068         Mercats municipals
# 21              58731068         Mercats municipals
# 22              58731068         Mercats municipals
# 23              58731068         Mercats municipals
# 24              58731069  Mercats i fires al carrer
# 25              58731068         Mercats municipals
# 26              58731068         Mercats municipals
# 27              58731069  Mercats i fires al carrer
# 28              58731068         Mercats municipals
# 29              58731068         Mercats municipals
# 30              58731068         Mercats municipals
# 31              58731068         Mercats municipals
# 32              58731068         Mercats municipals
# 33              58731068         Mercats municipals
# 34              58731069  Mercats i fires al carrer
# 35              58731068         Mercats municipals
# 36              58731069  Mercats i fires al carrer
# 37              58731068         Mercats municipals
# 38              58731068         Mercats municipals
# 39              58731068         Mercats municipals
# 40              58731068         Mercats municipals
# 41              58731068         Mercats municipals
# 42              58731068         Mercats municipals
# 43              58731068         Mercats municipals
# 44              58731068         Mercats municipals
# 45              58731068         Mercats municipals
# 46              58731068         Mercats municipals
# 47              58731068         Mercats municipals
# 48              58731068         Mercats municipals
# 49              58731068         Mercats municipals
# 50              58731068         Mercats municipals
#
#                                                                                  secondary_filters_fullpath  \
# 0                                            Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
# 1          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 2          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 3          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 4                                            Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
# 5          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 6          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 7          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 8          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 9          Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 10         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 11         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 12                                           Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
# 13         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 14         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 15                                           Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
# 16         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 17         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 18         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 19         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 20         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 21         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 22         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 23         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 24  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer
# 25         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 26         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 27  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer
# 28         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 29         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 30         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 31         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 32         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 33         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 34  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer
# 35         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 36  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer
# 37         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 38         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 39         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 40         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 41         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 42         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 43         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 44         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 45         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 46         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 47         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 48         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 49         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 50         Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
#
#     secondary_filters_tree secondary_filters_asia_id  geo_epgs_25831_x  \
# 0                      651                6,5103E+13       4,30537E+14
# 1                      651                6,5103E+13       4,30537E+14
# 2                      651                6,5103E+13       4,31213E+16
# 3                      651                6,5103E+13       4,29907E+16
# 4                      651                6,5103E+13       4,27241E+16
# 5                      651                6,5103E+13       4,27241E+16
# 6                      651                6,5103E+13        4,2926E+15
# 7                      651                6,5103E+13       4,31403E+15
# 8                      651                6,5103E+13       4,33591E+15
# 9                      651                6,5103E+13       4,34411E+16
# 10                     651                6,5103E+13       4,29303E+15
# 11                     651                6,5103E+13       4,29459E+16
# 12                     651                6,5103E+13        4,3186E+15
# 13                     651                6,5103E+13        4,3186E+15
# 14                     651                6,5103E+13       4,31904E+16
# 15                     651                6,5103E+13         4,265E+15
# 16                     651                6,5103E+13         4,265E+15
# 17                     651                6,5103E+13       4,30136E+16
# 18                     651                6,5103E+13       4,30198E+15
# 19                     651                6,5103E+13       4,31337E+15
# 20                     651                6,5103E+13         432192986
# 21                     651                6,5103E+13       4,28415E+16
# 22                     651                6,5103E+13       4,27382E+15
# 23                     651                6,5103E+13       4,27996E+15
# 24                     651                6,5103E+13        4,3193E+15
# 25                     651                6,5103E+13        4,3193E+15
# 26                     651                6,5103E+13       4,29129E+15
# 27                     651                6,5103E+13       4,30052E+15
# 28                     651                6,5103E+13       4,30052E+15
# 29                     651                6,5103E+13        4,3079E+15
# 30                     651                6,5103E+13       4,31288E+16
# 31                     651                6,5103E+13       4,28406E+15
# 32                     651                6,5103E+13       4,27561E+16
# 33                     651                6,5103E+13          4,28E+15
# 34                     651                6,5103E+13       4,30764E+16
# 35                     651                6,5103E+13       4,30764E+16
# 36                     651                6,5103E+13       4,29907E+16
# 37                     651                6,5103E+13       4,29907E+16
# 38                     651                6,5103E+13        4,3221E+16
# 39                     651                6,5103E+13       4,31452E+15
# 40                     651                6,5103E+13       4,30681E+15
# 41                     651                6,5103E+13       4,32186E+15
# 42                     651                6,5103E+13       4,33582E+16
# 43                     651                6,5103E+13       4,32853E+15
# 44                     651                6,5103E+13       4,30128E+15
# 45                     651                6,5103E+13       4,28343E+16
# 46                     651                6,5103E+13       4,29782E+15
# 47                     651                6,5103E+13       4,30952E+15
# 48                     651                6,5103E+13       4,33679E+15
# 49                     651                6,5103E+13       4,31663E+15
# 50                     651                6,5103E+13         430903145
#
#    geo_epgs_25831_y geo_epgs_4326_x  geo_epgs_4326_y
# 0         4,583E+15     4,13956E+15      2,16907E+15
# 1         4,583E+15     4,13956E+15      2,16907E+15
# 2       4,58412E+15     4,14057E+15      2,17703E+15
# 3       4,58123E+15     4,13796E+15      2,16174E+15
# 4       4,58176E+15     4,13841E+15       2,1298E+16
# 5       4,58176E+15     4,13841E+15       2,1298E+16
# 6       4,58348E+15     4,13997E+15      2,15375E+16
# 7       4,58863E+15     4,14463E+16      2,17879E+16
# 8       4,58554E+13     4,14187E+15      2,20532E+16
# 9       4,58559E+15     4,14192E+16      2,21513E+16
# 10      4,58216E+15     4,13879E+15      2,15441E+16
# 11      4,58614E+15     4,14237E+15      2,15581E+15
# 12      4,58889E+15     4,14487E+15      2,18423E+16
# 13      4,58889E+15     4,14487E+15      2,18423E+16
# 14      4,58593E+15      4,1422E+15      2,18509E+16
# 15      4,58352E+15     4,13998E+16      2,12072E+16
# 16      4,58352E+15     4,13998E+16      2,12072E+16
# 17      4,58385E+15     4,14032E+16      2,16418E+16
# 18      4,58816E+15      4,1442E+15      2,16443E+14
# 19      4,59034E+16     4,14617E+15      2,17781E+16
# 20       4587353979     4,14349E+15      2,18839E+16
# 21      4,58315E+15     4,13967E+15      2,14368E+15
# 22      4,58352E+15     4,13999E+15      2,13128E+15
# 23      4,58415E+14     4,14057E+15      2,13855E+15
# 24       4,5836E+15     4,14011E+16      2,18567E+16
# 25       4,5836E+15     4,14011E+16      2,18567E+16
# 26      4,58452E+15     4,14091E+15      2,15206E+16
# 27      4,58142E+15     4,13813E+15      2,16345E+16
# 28      4,58142E+15     4,13813E+15      2,16345E+16
# 29       4,5815E+15      4,1382E+16      2,17227E+16
# 30      4,58198E+16     4,13864E+15      2,17818E+16
# 31      4,58076E+15     4,13752E+15      2,14385E+15
# 32      4,58072E+15     4,13747E+15      2,13375E+16
# 33      4,57912E+15     4,13604E+15      2,13919E+16
# 34       4,5816E+13      4,1383E+15      2,17195E+16
# 35       4,5816E+13      4,1383E+15      2,17195E+16
# 36      4,58123E+15     4,13796E+15      2,16174E+15
# 37      4,58123E+15     4,13796E+15      2,16174E+15
# 38      4,58129E+15     4,13802E+15      2,18928E+14
# 39      4,58561E+15     4,14192E+16      2,17972E+15
# 40      4,58779E+15     4,14387E+15      2,17025E+15
# 41      4,58433E+14     4,14076E+15      2,18864E+16
# 42      4,58358E+15      4,1401E+15      2,20543E+16
# 43      4,58563E+15     4,14195E+15      2,19649E+16
# 44       4,5846E+15     4,14099E+16      2,16399E+16
# 45      4,58619E+15     4,14241E+15      2,14245E+15
# 46      4,58679E+13     4,14296E+15      2,15961E+16
# 47      4,58688E+15     4,14305E+16       2,1736E+16
# 48      4,58746E+15      4,1436E+15      2,20617E+15
# 49      4,58302E+15     4,13958E+15      2,18254E+15
# 50       4590148469       4,146E+15      2,17264E+16
#
# [51 rows x 36 columns]

# %%
df_mercados.head()
# Out:
#     register_id                          name  institution_id  \
# 0  ﻿92086009449        Mercat de La Concepció             NaN
# 1  ﻿92086009449        Mercat de La Concepció             NaN
# 2  ﻿92086009450  Mercat de la Sagrada Família             NaN
# 3  ﻿92086009452         Mercat de Sant Antoni             NaN
# 4  ﻿92086009457           Mercat de Les Corts             NaN
#
#    institution_name created     modified  addresses_roadtype_id  \
# 0               NaN   31044  44732,38445                    NaN
# 1               NaN   31044  44732,38445                    NaN
# 2               NaN   31044  44728,48622                    NaN
# 3               NaN   33049  44768,41858                    NaN
# 4               NaN   31044  44732,38082                    NaN
#
#    addresses_roadtype_name  addresses_road_id        addresses_road_name  ...  \
# 0                      NaN              18505             Carrer d'Aragó  ...
# 1                      NaN              18505             Carrer d'Aragó  ...
# 2                      NaN             238400          Carrer de Padilla  ...
# 3                      NaN             349706  Carrer del Comte d'Urgell  ...
# 4                      NaN             343903    Travessera de les Corts  ...
#
#    values_description  secondary_filters_id  secondary_filters_name  \
# 0                 NaN              66731068                WiFi BCN
# 1                 NaN              58731068      Mercats municipals
# 2                 NaN              58731068      Mercats municipals
# 3                 NaN              58731068      Mercats municipals
# 4                 NaN              66731068                WiFi BCN
#
#                                                                          secondary_filters_fullpath  \
# 0                                    Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
# 1  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 2  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 3  Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals
# 4                                    Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN
#
#    secondary_filters_tree secondary_filters_asia_id  geo_epgs_25831_x  \
# 0                     651                6,5103E+13       4,30537E+14
# 1                     651                6,5103E+13       4,30537E+14
# 2                     651                6,5103E+13       4,31213E+16
# 3                     651                6,5103E+13       4,29907E+16
# 4                     651                6,5103E+13       4,27241E+16
#
#   geo_epgs_25831_y geo_epgs_4326_x  geo_epgs_4326_y
# 0        4,583E+15     4,13956E+15      2,16907E+15
# 1        4,583E+15     4,13956E+15      2,16907E+15
# 2      4,58412E+15     4,14057E+15      2,17703E+15
# 3      4,58123E+15     4,13796E+15      2,16174E+15
# 4      4,58176E+15     4,13841E+15       2,1298E+16
#
# [5 rows x 36 columns]

# %%
df_mercados.columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %%
# Crear un diccionario a partir del dataframe relativo al padron (dict_padro)
import numpy as np
padro = pd.read_csv('C:/Users/Santiago/Desktop/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/00_CHALLENGES/99_datasets/2021_padro.csv',sep=',')



dict_padro={}
for barri in padro['Nom_Barri'].drop_duplicates():
  dict_padro[barri]={}
  dict_padro[barri]['Dones']=np.sum(padro[(padro['Nom_Barri']==barri) & (padro['Sexe']=='Dones')]['Nombre'].values)
  dict_padro[barri]['Homes']=np.sum(padro[(padro['Nom_Barri']==barri) & (padro['Sexe']=='Homes')]['Nombre'].values)
  dict_padro[barri]['Total']=dict_padro[barri]['Dones']+dict_padro[barri]['Homes']

dict_padro
# Out:
# {'el Raval': {'Dones': 22466, 'Homes': 26222, 'Total': 48688},
#  'el Barri Gòtic': {'Dones': 8843, 'Homes': 14007, 'Total': 22850},
#  'la Barceloneta': {'Dones': 7647, 'Homes': 7478, 'Total': 15125},
#  'Sant Pere, Santa Caterina i la Ribera': {'Dones': 11431,
#   'Homes': 11578,
#   'Total': 23009},
#  'el Fort Pienc': {'Dones': 17443, 'Homes': 16002, 'Total': 33445},
#  'la Sagrada Família': {'Dones': 28118, 'Homes': 24046, 'Total': 52164},
#  "la Dreta de l'Eixample": {'Dones': 23431, 'Homes': 20657, 'Total': 44088},
#  "l'Antiga Esquerra de l'Eixample": {'Dones': 22685,
#   'Homes': 20361,
#   'Total': 43046},
#  "la Nova Esquerra de l'Eixample": {'Dones': 30843,
#   'Homes': 27063,
#   'Total': 57906},
#  'Sant Antoni': {'Dones': 20253, 'Homes': 18447, 'Total': 38700},
#  'el Poble Sec': {'Dones': 20429, 'Homes': 19775, 'Total': 40204},
#  'la Marina del Prat Vermell': {'Dones': 657, 'Homes': 699, 'Total': 1356},
#  'la Marina de Port': {'Dones': 16141, 'Homes': 14951, 'Total': 31092},
#  'la Font de la Guatlla': {'Dones': 5377, 'Homes': 4862, 'Total': 10239},
#  'Hostafrancs': {'Dones': 8378, 'Homes': 7724, 'Total': 16102},
#  'la Bordeta': {'Dones': 10169, 'Homes': 9282, 'Total': 19451},
#  'Sants - Badal': {'Dones': 13239, 'Homes': 11664, 'Total': 24903},
#  'Sants': {'Dones': 22600, 'Homes': 21079, 'Total': 43679},
#  'les Corts': {'Dones': 24686, 'Homes': 21257, 'Total': 45943},
#  'la Maternitat i Sant Ramon': {'Dones': 12722,
#   'Homes': 11103,
#   'Total': 23825},
#  'Pedralbes': {'Dones': 6306, 'Homes': 5502, 'Total': 11808},
#  'Vallvidrera, el Tibidabo i les Planes': {'Dones': 2405,
#   'Homes': 2355,
#   'Total': 4760},
#  'Sarrià': {'Dones': 13243, 'Homes': 11526, 'Total': 24769},
#  'les Tres Torres': {'Dones': 8712, 'Homes': 7644, 'Total': 16356},
#  'Sant Gervasi - la Bonanova': {'Dones': 14003,
#   'Homes': 11981,
#   'Total': 25984},
#  'Sant Gervasi - Galvany': {'Dones': 26036, 'Homes': 21310, 'Total': 47346},
#  'el Putxet i el Farró': {'Dones': 16254, 'Homes': 13732, 'Total': 29986},
#  'Vallcarca i els Penitents': {'Dones': 8719, 'Homes': 7606, 'Total': 16325},
#  'el Coll': {'Dones': 4098, 'Homes': 3590, 'Total': 7688},
#  'la Salut': {'Dones': 7212, 'Homes': 6243, 'Total': 13455},
#  'la Vila de Gràcia': {'Dones': 27388, 'Homes': 23068, 'Total': 50456},
#  "el Camp d'en Grassot i Gràcia Nova": {'Dones': 19121,
#   'Homes': 16231,
#   'Total': 35352},
#  'el Baix Guinardó': {'Dones': 13877, 'Homes': 11965, 'Total': 25842},
#  'Can Baró': {'Dones': 4919, 'Homes': 4401, 'Total': 9320},
#  'el Guinardó': {'Dones': 19865, 'Homes': 17460, 'Total': 37325},
#  "la Font d'en Fargues": {'Dones': 4978, 'Homes': 4527, 'Total': 9505},
#  'el Carmel': {'Dones': 17166, 'Homes': 15558, 'Total': 32724},
#  'la Teixonera': {'Dones': 6248, 'Homes': 5796, 'Total': 12044},
#  'Sant Genís dels Agudells': {'Dones': 3896, 'Homes': 3489, 'Total': 7385},
#  'Montbau': {'Dones': 2812, 'Homes': 2302, 'Total': 5114},
#  "la Vall d'Hebron": {'Dones': 3169, 'Homes': 2763, 'Total': 5932},
#  'la Clota': {'Dones': 335, 'Homes': 363, 'Total': 698},
#  'Horta': {'Dones': 14918, 'Homes': 13137, 'Total': 28055},
#  'Vilapicina i la Torre Llobeta': {'Dones': 13999,
#   'Homes': 11876,
#   'Total': 25875},
#  'Porta': {'Dones': 14731, 'Homes': 13065, 'Total': 27796},
#  'el Turó de la Peira': {'Dones': 8609, 'Homes': 7577, 'Total': 16186},
#  'Can Peguera': {'Dones': 1181, 'Homes': 1034, 'Total': 2215},
#  'la Guineueta': {'Dones': 8213, 'Homes': 7054, 'Total': 15267},
#  'Canyelles': {'Dones': 3584, 'Homes': 3229, 'Total': 6813},
#  'les Roquetes': {'Dones': 8576, 'Homes': 7987, 'Total': 16563},
#  'Verdun': {'Dones': 6880, 'Homes': 5985, 'Total': 12865},
#  'la Prosperitat': {'Dones': 14282, 'Homes': 12586, 'Total': 26868},
#  'la Trinitat Nova': {'Dones': 3966, 'Homes': 3662, 'Total': 7628},
#  'Torre Baró': {'Dones': 1462, 'Homes': 1461, 'Total': 2923},
#  'Ciutat Meridiana': {'Dones': 5688, 'Homes': 5464, 'Total': 11152},
#  'Vallbona': {'Dones': 716, 'Homes': 685, 'Total': 1401},
#  'la Trinitat Vella': {'Dones': 5162, 'Homes': 5351, 'Total': 10513},
#  'Baró de Viver': {'Dones': 1355, 'Homes': 1298, 'Total': 2653},
#  'el Bon Pastor': {'Dones': 6870, 'Homes': 6860, 'Total': 13730},
#  'Sant Andreu': {'Dones': 30727, 'Homes': 27498, 'Total': 58225},
#  'la Sagrera': {'Dones': 15723, 'Homes': 13845, 'Total': 29568},
#  'el Congrés i els Indians': {'Dones': 7746, 'Homes': 6803, 'Total': 14549},
#  'Navas': {'Dones': 11888, 'Homes': 10411, 'Total': 22299},
#  "el Camp de l'Arpa del Clot": {'Dones': 20621,
#   'Homes': 18217,
#   'Total': 38838},
#  'el Clot': {'Dones': 13956, 'Homes': 12803, 'Total': 26759},
#  'el Parc i la Llacuna del Poblenou': {'Dones': 8219,
#   'Homes': 7695,
#   'Total': 15914},
#  'la Vila Olímpica del Poblenou': {'Dones': 4780,
#   'Homes': 4615,
#   'Total': 9395},
#  'el Poblenou': {'Dones': 17675, 'Homes': 16736, 'Total': 34411},
#  'Diagonal Mar i el Front Marítim del Poblenou': {'Dones': 6938,
#   'Homes': 6598,
#   'Total': 13536},
#  'el Besòs i el Maresme': {'Dones': 12440, 'Homes': 13676, 'Total': 26116},
#  'Provençals del Poblenou': {'Dones': 11036, 'Homes': 10149, 'Total': 21185},
#  'Sant Martí de Provençals': {'Dones': 13958, 'Homes': 12271, 'Total': 26229},
#  'la Verneda i la Pau': {'Dones': 15160, 'Homes': 13638, 'Total': 28798}}

# %%
# Carregar csv mercados
#TODO

mercados.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Santiago\Desktop\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\00_CHALLENGES\02_DATA_ANALYSIS\PRACTICA_1\PRA1b_captura_datos_2022_alumni.ipynb Celda 15 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Santiago/Desktop/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/00_CHALLENGES/02_DATA_ANALYSIS/PRACTICA_1/PRA1b_captura_datos_2022_alumni.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Carregar csv mercados
#       <a href='vscode-notebook-cell:/c%3A/Users/Santiago/Desktop/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/00_CHALLENGES/02_DATA_ANALYSIS/PRACTICA_1/PRA1b_captura_datos_2022_alumni.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> #TODO
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Santiago/Desktop/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/00_CHALLENGES/02_DATA_ANALYSIS/PRACTICA_1/PRA1b_captura_datos_2022_alumni.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> mercados.head()
#
# NameError: name 'mercados' is not defined

# %%
## Crear un diccionario a partir del dataframe relativo a los mercados(dict_mercados)
#TODO
df_mercados.drop_duplicates(subset='register_id',inplace=True)
df_mercados.index=df_mercados['register_id']
mercados_dict = df_mercados.to_dict('index')
print(mercados_dict)
# Out:
# {'\ufeff92086009449': {'register_id': '\ufeff92086009449', 'name': 'Mercat de La Concepció', 'institution_id': nan, 'institution_name': nan, 'created': '31044', 'modified': '44732,38445', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 18505, 'addresses_road_name': "Carrer d'Aragó", 'addresses_start_street_number': 311, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 7, 'addresses_neighborhood_name': "la Dreta de l'Eixample", 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8009, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161780, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132314', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 66731068, 'secondary_filters_name': 'WiFi BCN', 'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN", 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,30537E+14', 'geo_epgs_25831_y': '4,583E+15', 'geo_epgs_4326_x': '4,13956E+15', 'geo_epgs_4326_y': '2,16907E+15'}, '\ufeff92086009450': {'register_id': '\ufeff92086009450', 'name': 'Mercat de la Sagrada Família', 'institution_id': nan, 'institution_name': nan, 'created': '31044', 'modified': '44728,48622', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 238400, 'addresses_road_name': 'Carrer de Padilla', 'addresses_start_street_number': 255, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 6, 'addresses_neighborhood_name': 'la Sagrada Família', 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8013, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161781, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132324', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 58731068, 'secondary_filters_name': 'Mercats municipals', 'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals', 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,31213E+16', 'geo_epgs_25831_y': '4,58412E+15', 'geo_epgs_4326_x': '4,14057E+15', 'geo_epgs_4326_y': '2,17703E+15'}, '\ufeff92086009452': {'register_id': '\ufeff92086009452', 'name': 'Mercat de Sant Antoni', 'institution_id': nan, 'institution_name': nan, 'created': '33049', 'modified': '44768,41858', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 349706, 'addresses_road_name': "Carrer del Comte d'Urgell", 'addresses_start_street_number': 1, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 10, 'addresses_neighborhood_name': 'Sant Antoni', 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8011, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161783, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132300', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 58731068, 'secondary_filters_name': 'Mercats municipals', 'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals', 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,29907E+16', 'geo_epgs_25831_y': '4,58123E+15', 'geo_epgs_4326_x': '4,13796E+15', 'geo_epgs_4326_y': '2,16174E+15'}, '\ufeff92086009457': {'register_id': '\ufeff92086009457', 'name': 'Mercat de Les Corts', 'institution_id': nan, 'institution_name': nan, 'cr ...

# %%
# Crear dict completo
#TODO
completo_dict = mercados_dict | padro_dict
completo_dict


for k,v in mercados_dict.items():
  if v['addresses_neighborhood_name'] in dict_padro.keys():
    mercados_dict[k]['padro']=dict_padro[v['addresses_neighborhood_name']]
  else:
    mercados_dict[k]['padro']['Oficina']='NA'

mercados_dict
# Out:
# {'\ufeff92086009449': {'register_id': '\ufeff92086009449',
#   'name': 'Mercat de La Concepció',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38445',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18505,
#   'addresses_road_name': "Carrer d'Aragó",
#   'addresses_start_street_number': 311,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 7,
#   'addresses_neighborhood_name': "la Dreta de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8009,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161780,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132314',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30537E+14',
#   'geo_epgs_25831_y': '4,583E+15',
#   'geo_epgs_4326_x': '4,13956E+15',
#   'geo_epgs_4326_y': '2,16907E+15',
#   'padro': {'Dones': 23431, 'Homes': 20657, 'Total': 44088}},
#  '\ufeff92086009450': {'register_id': '\ufeff92086009450',
#   'name': 'Mercat de la Sagrada Família',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48622',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 238400,
#   'addresses_road_name': 'Carrer de Padilla',
#   'addresses_start_street_number': 255,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 6,
#   'addresses_neighborhood_name': 'la Sagrada Família',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161781,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31213E+16',
#   'geo_epgs_25831_y': '4,58412E+15',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,17703E+15',
#   'padro': {'Dones': 28118, 'Homes': 24046, 'Total': 52164}},
#  '\ufeff92086009452': {'register_id': '\ufeff92086009452',
#   'name': 'Mercat de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '33049',
#   'modified': '44768,41858',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "Carrer del Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161783,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009457': {'register_id': '\ufeff92086009457',
#   'name': 'Mercat de Les Corts',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38082',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 343903,
#   'addresses_road_name': 'Travessera de les Corts',
#   'addresses_start_street_number': 215,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 19,
#   'addresses_neighborhood_name': 'les Corts',
#   'addresses_district_id': 4,
#   'addresses_district_name': 'Les Corts',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162504,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '667570336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27241E+16',
#   'geo_epgs_25831_y': '4,58176E+15',
#   'geo_epgs_4326_x': '4,13841E+15',
#   'geo_epgs_4326_y': '2,1298E+16',
#   'padro': {'Dones': 24686, 'Homes': 21257, 'Total': 45943}},
#  '\ufeff92086009773': {'register_id': '\ufeff92086009773',
#   'name': 'Mercat de la Llibertat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44732,37875',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 179107,
#   'addresses_road_name': 'Plaça de la Llibertat',
#   'addresses_start_street_number': 27,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 31,
#   'addresses_neighborhood_name': 'la Vila de Gràcia',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8012,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162390,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '933687946',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,2926E+15',
#   'geo_epgs_25831_y': '4,58348E+15',
#   'geo_epgs_4326_x': '4,13997E+15',
#   'geo_epgs_4326_y': '2,15375E+16',
#   'padro': {'Dones': 27388, 'Homes': 23068, 'Total': 50456}},
#  '\ufeff92086009781': {'register_id': '\ufeff92086009781',
#   'name': 'Mercat de Montserrat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48757',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 120807,
#   'addresses_road_name': 'Via Favència',
#   'addresses_start_street_number': 241,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 50,
#   'addresses_neighborhood_name': 'les Roquetes',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162008,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132341',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31403E+15',
#   'geo_epgs_25831_y': '4,58863E+15',
#   'geo_epgs_4326_x': '4,14463E+16',
#   'geo_epgs_4326_y': '2,17879E+16',
#   'padro': {'Dones': 8576, 'Homes': 7987, 'Total': 16563}},
#  '\ufeff92086009789': {'register_id': '\ufeff92086009789',
#   'name': 'Mercat de Sant Martí',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43696',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 270107,
#   'addresses_road_name': 'Carrer de Puigcerdà',
#   'addresses_start_street_number': 206,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 73,
#   'addresses_neighborhood_name': 'la Verneda i la Pau',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161886,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132297',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33591E+15',
#   'geo_epgs_25831_y': '4,58554E+13',
#   'geo_epgs_4326_x': '4,14187E+15',
#   'geo_epgs_4326_y': '2,20532E+16',
#   'padro': {'Dones': 15160, 'Homes': 13638, 'Total': 28798}},
#  '\ufeff92086009790': {'register_id': '\ufeff92086009790',
#   'name': 'Mercat del Besòs',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44818,36006',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 165601,
#   'addresses_road_name': 'C Jaume Huguet',
#   'addresses_start_street_number': 38,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 70,
#   'addresses_neighborhood_name': 'el Besòs i el Maresme',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8019,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161887,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132305',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,34411E+16',
#   'geo_epgs_25831_y': '4,58559E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,21513E+16',
#   'padro': {'Dones': 12440, 'Homes': 13676, 'Total': 26116}},
#  '\ufeff92086009451': {'register_id': '\ufeff92086009451',
#   'name': 'Mercat del Ninot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58065',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 191204,
#   'addresses_road_name': 'Carrer de Mallorca',
#   'addresses_start_street_number': 133,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 8,
#   'addresses_neighborhood_name': "l'Antiga Esquerra de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8036,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161782,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132322',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29303E+15',
#   'geo_epgs_25831_y': '4,58216E+15',
#   'geo_epgs_4326_x': '4,13879E+15',
#   'geo_epgs_4326_y': '2,15441E+16',
#   'padro': {'Dones': 22685, 'Homes': 20361, 'Total': 43046}},
#  '\ufeff92086009775': {'register_id': '\ufeff92086009775',
#   'name': 'Mercat del Carmel',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49168',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 185700,
#   'addresses_road_name': 'C Llobregós',
#   'addresses_start_street_number': 149,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 37,
#   'addresses_neighborhood_name': 'el Carmel',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162003,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132335',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29459E+16',
#   'geo_epgs_25831_y': '4,58614E+15',
#   'geo_epgs_4326_x': '4,14237E+15',
#   'geo_epgs_4326_y': '2,15581E+15',
#   'padro': {'Dones': 17166, 'Homes': 15558, 'Total': 32724}},
#  '\ufeff92086009783': {'register_id': '\ufeff92086009783',
#   'name': 'Mercat de La Trinitat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48686',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 250507,
#   'addresses_road_name': 'Carrer de la Pedrosa',
#   'addresses_start_street_number': 21,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 53,
#   'addresses_neighborhood_name': 'la Trinitat Nova',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162010,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132343',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3186E+15',
#   'geo_epgs_25831_y': '4,58889E+15',
#   'geo_epgs_4326_x': '4,14487E+15',
#   'geo_epgs_4326_y': '2,18423E+16',
#   'padro': {'Dones': 3966, 'Homes': 3662, 'Total': 7628}},
#  '\ufeff92086009785': {'register_id': '\ufeff92086009785',
#   'name': 'Mercat de Felip II',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48279',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 121402,
#   'addresses_road_name': 'Carrer de Felip II',
#   'addresses_start_street_number': 118,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 61,
#   'addresses_neighborhood_name': 'la Sagrera',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8027,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162012,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132337',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31904E+16',
#   'geo_epgs_25831_y': '4,58593E+15',
#   'geo_epgs_4326_x': '4,1422E+15',
#   'geo_epgs_4326_y': '2,18509E+16',
#   'padro': {'Dones': 15723, 'Homes': 13845, 'Total': 29568}},
#  '\ufeff92086009459': {'register_id': '\ufeff92086009459',
#   'name': 'Mercat de Sarrià',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,49005',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 278007,
#   'addresses_road_name': 'Pg Reina Elisenda Montcada',
#   'addresses_start_street_number': 8,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 23,
#   'addresses_neighborhood_name': 'Sarrià',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8034,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161787,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132326',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,265E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13998E+16',
#   'geo_epgs_4326_y': '2,12072E+16',
#   'padro': {'Dones': 13243, 'Homes': 11526, 'Total': 24769}},
#  '\ufeff92086009463': {'register_id': '\ufeff92086009463',
#   'name': "Mercat de l'Abaceria Central",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,5772',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 305100,
#   'addresses_road_name': 'Pg Sant Joan',
#   'addresses_start_street_number': 181,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8037,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161639,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132313',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30136E+16',
#   'geo_epgs_25831_y': '4,58385E+15',
#   'geo_epgs_4326_x': '4,14032E+16',
#   'geo_epgs_4326_y': '2,16418E+16',
#   'padro': {'Dones': 19121, 'Homes': 16231, 'Total': 35352}},
#  '\ufeff92086019717': {'register_id': '\ufeff92086019717',
#   'name': 'Mercat de Canyelles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31862',
#   'modified': '44728,48193',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18254,
#   'addresses_road_name': "Carrer d'Antonio Machado",
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 49,
#   'addresses_neighborhood_name': 'Canyelles',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 166176,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30198E+15',
#   'geo_epgs_25831_y': '4,58816E+15',
#   'geo_epgs_4326_x': '4,1442E+15',
#   'geo_epgs_4326_y': '2,16443E+14',
#   'padro': {'Dones': 3584, 'Homes': 3229, 'Total': 6813}},
#  '\ufeff92086009782': {'register_id': '\ufeff92086009782',
#   'name': 'Mercat de Ciutat Meridiana',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48264',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 92950,
#   'addresses_road_name': 'Carrer de Costabona',
#   'addresses_start_street_number': 4,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162009,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31337E+15',
#   'geo_epgs_25831_y': '4,59034E+16',
#   'geo_epgs_4326_x': '4,14617E+15',
#   'geo_epgs_4326_y': '2,17781E+16',
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}},
#  '\ufeff92086009787': {'register_id': '\ufeff92086009787',
#   'name': 'Mercat de Sant Andreu',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44819,56347',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208307,
#   'addresses_road_name': 'Plaça del Mercadal',
#   'addresses_start_street_number': 41,
#   'addresses_end_street_number': 41.0,
#   'addresses_neighborhood_id': 60,
#   'addresses_neighborhood_name': 'Sant Andreu',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162013,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132342',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '432192986',
#   'geo_epgs_25831_y': '4587353979',
#   'geo_epgs_4326_x': '4,14349E+15',
#   'geo_epgs_4326_y': '2,18839E+16',
#   'padro': {'Dones': 30727, 'Homes': 27498, 'Total': 58225}},
#  '\ufeff92086009458': {'register_id': '\ufeff92086009458',
#   'name': 'Mercat de Galvany',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48292',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 318804,
#   'addresses_road_name': 'Carrer de Santaló',
#   'addresses_start_street_number': 65,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 26,
#   'addresses_neighborhood_name': 'Sant Gervasi - Galvany',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8021,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161786,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132317',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28415E+16',
#   'geo_epgs_25831_y': '4,58315E+15',
#   'geo_epgs_4326_x': '4,13967E+15',
#   'geo_epgs_4326_y': '2,14368E+15',
#   'padro': {'Dones': 26036, 'Homes': 21310, 'Total': 47346}},
#  '\ufeff92086009460': {'register_id': '\ufeff92086009460',
#   'name': 'Mercat de Les Tres Torres',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48724',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 357103,
#   'addresses_road_name': 'Carrer dels Vergós',
#   'addresses_start_street_number': 2,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 24,
#   'addresses_neighborhood_name': 'les Tres Torres',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8017,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161788,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132327',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27382E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13999E+15',
#   'geo_epgs_4326_y': '2,13128E+15',
#   'padro': {'Dones': 8712, 'Homes': 7644, 'Total': 16356}},
#  '\ufeff92086009462': {'register_id': '\ufeff92086009462',
#   'name': 'Mercat de Sant Gervasi',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38267',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 231706,
#   'addresses_road_name': 'Pl Joaquim Folguera',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 25,
#   'addresses_neighborhood_name': 'Sant Gervasi - la Bonanova',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8022,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161789,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132325',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27996E+15',
#   'geo_epgs_25831_y': '4,58415E+14',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,13855E+15',
#   'padro': {'Dones': 14003, 'Homes': 11981, 'Total': 25984}},
#  '\ufeff92086009468': {'register_id': '\ufeff92086009468',
#   'name': 'Mercat Encants Vells Fira de Bellcaire',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57901',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 73900,
#   'addresses_road_name': 'Carrer de los Castillejos',
#   'addresses_start_street_number': 158,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161792,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132328',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3193E+15',
#   'geo_epgs_25831_y': '4,5836E+15',
#   'geo_epgs_4326_x': '4,14011E+16',
#   'geo_epgs_4326_y': '2,18567E+16',
#   'padro': {'Dones': 17443, 'Homes': 16002, 'Total': 33445}},
#  '\ufeff92086009464': {'register_id': '\ufeff92086009464',
#   'name': 'Mercat de Lesseps',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,37627',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 356803,
#   'addresses_road_name': 'Carrer de Verdi',
#   'addresses_start_street_number': 200,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 30,
#   'addresses_neighborhood_name': 'la Salut',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161790,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132319',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29129E+15',
#   'geo_epgs_25831_y': '4,58452E+15',
#   'geo_epgs_4326_x': '4,14091E+15',
#   'geo_epgs_4326_y': '2,15206E+16',
#   'padro': {'Dones': 7212, 'Homes': 6243, 'Total': 13455}},
#  '\ufeff92086009467': {'register_id': '\ufeff92086009467',
#   'name': 'Mercat Encants de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44770,57452',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161791,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30052E+15',
#   'geo_epgs_25831_y': '4,58142E+15',
#   'geo_epgs_4326_x': '4,13813E+15',
#   'geo_epgs_4326_y': '2,16345E+16',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009447': {'register_id': '\ufeff92086009447',
#   'name': 'Mercat de Sant Josep - La Boqueria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57829',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'Carrer la Rambla',
#   'addresses_start_street_number': 89,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 1,
#   'addresses_neighborhood_name': 'el Raval',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161741,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132303',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Informació',
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3079E+15',
#   'geo_epgs_25831_y': '4,5815E+15',
#   'geo_epgs_4326_x': '4,1382E+16',
#   'geo_epgs_4326_y': '2,17227E+16',
#   'padro': {'Dones': 22466, 'Homes': 26222, 'Total': 48688}},
#  '\ufeff92086009448': {'register_id': '\ufeff92086009448',
#   'name': 'Mercat de Santa Caterina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58194',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 132952,
#   'addresses_road_name': 'Av Francesc Cambó',
#   'addresses_start_street_number': 16,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 4,
#   'addresses_neighborhood_name': 'Sant Pere, Santa Caterina i la Ribera',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161718,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132298',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31288E+16',
#   'geo_epgs_25831_y': '4,58198E+16',
#   'geo_epgs_4326_x': '4,13864E+15',
#   'geo_epgs_4326_y': '2,17818E+16',
#   'padro': {'Dones': 11431, 'Homes': 11578, 'Total': 23009}},
#  '\ufeff92086009454': {'register_id': '\ufeff92086009454',
#   'name': "Mercat d'Hostafrancs",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,4821',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 94809,
#   'addresses_road_name': 'Carrer de la Creu Coberta',
#   'addresses_start_street_number': 93,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 15,
#   'addresses_neighborhood_name': 'Hostafrancs',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8014,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161784,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132307',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28406E+15',
#   'geo_epgs_25831_y': '4,58076E+15',
#   'geo_epgs_4326_x': '4,13752E+15',
#   'geo_epgs_4326_y': '2,14385E+15',
#   'padro': {'Dones': 8378, 'Homes': 7724, 'Total': 16102}},
#  '\ufeff92086009455': {'register_id': '\ufeff92086009455',
#   'name': 'Mercat de Sants',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44768,41922',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 304209,
#   'addresses_road_name': 'C Sant Jordi',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 18,
#   'addresses_neighborhood_name': 'Sants',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162421,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '932694472',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27561E+16',
#   'geo_epgs_25831_y': '4,58072E+15',
#   'geo_epgs_4326_x': '4,13747E+15',
#   'geo_epgs_4326_y': '2,13375E+16',
#   'padro': {'Dones': 22600, 'Homes': 21079, 'Total': 43679}},
#  '\ufeff92086009456': {'register_id': '\ufeff92086009456',
#   'name': 'Mercat de La Marina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,39465',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 369408,
#   'addresses_road_name': 'Passeig de la Zona Franca',
#   'addresses_start_street_number': 178,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 13,
#   'addresses_neighborhood_name': 'la Marina de Port',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8038,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161785,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132308',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28E+15',
#   'geo_epgs_25831_y': '4,57912E+15',
#   'geo_epgs_4326_x': '4,13604E+15',
#   'geo_epgs_4326_y': '2,13919E+16',
#   'padro': {'Dones': 16141, 'Homes': 14951, 'Total': 31092}},
#  '\ufeff92086011624': {'register_id': '\ufeff92086011624',
#   'name': 'Mercat de les Flors *Les Rambles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31128',
#   'modified': '44727,41879',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'C la Rambla',
#   'addresses_start_street_number': 116,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 2,
#   'addresses_neighborhood_name': 'el Barri Gòtic',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 163447,
#   'values_attribute_id': 100050,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'No tenen telèfon',
#   'values_value': '-',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30764E+16',
#   'geo_epgs_25831_y': '4,5816E+13',
#   'geo_epgs_4326_x': '4,1383E+15',
#   'geo_epgs_4326_y': '2,17195E+16',
#   'padro': {'Dones': 8843, 'Homes': 14007, 'Total': 22850}},
#  '\ufeff96058202955': {'register_id': '\ufeff96058202955',
#   'name': 'Mercat Dominical de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '35122',
#   'modified': '44755,4564',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 189742,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Mercat de Sant Antoni',
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009445': {'register_id': '\ufeff92086009445',
#   'name': 'Mercat de La Barceloneta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44825,41282',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 260908,
#   'addresses_road_name': 'Plaça del Poeta Boscà',
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 3,
#   'addresses_neighborhood_name': 'la Barceloneta',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162818,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132304',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3221E+16',
#   'geo_epgs_25831_y': '4,58129E+15',
#   'geo_epgs_4326_x': '4,13802E+15',
#   'geo_epgs_4326_y': '2,18928E+14',
#   'padro': {'Dones': 7647, 'Homes': 7478, 'Total': 15125}},
#  '\ufeff92086009776': {'register_id': '\ufeff92086009776',
#   'name': 'Mercat del Guinardó',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,42299',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 334403,
#   'addresses_road_name': 'C Teodor Llorente',
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 35,
#   'addresses_neighborhood_name': 'el Guinardó',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8041,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162004,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132332',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31452E+15',
#   'geo_epgs_25831_y': '4,58561E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,17972E+15',
#   'padro': {'Dones': 19865, 'Homes': 17460, 'Total': 37325}},
#  '\ufeff92086009779': {'register_id': '\ufeff92086009779',
#   'name': 'Mercat de La Guineueta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44776,56573',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 351901,
#   'addresses_road_name': 'Passeig de Valldaura',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 48,
#   'addresses_neighborhood_name': 'la Guineueta',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162006,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132338',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30681E+15',
#   'geo_epgs_25831_y': '4,58779E+15',
#   'geo_epgs_4326_x': '4,14387E+15',
#   'geo_epgs_4326_y': '2,17025E+15',
#   'padro': {'Dones': 8213, 'Homes': 7054, 'Total': 15267}},
#  '\ufeff92086009788': {'register_id': '\ufeff92086009788',
#   'name': 'Mercat del Clot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,4115',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 209004,
#   'addresses_road_name': 'Pl Mercat',
#   'addresses_start_street_number': 26,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 65,
#   'addresses_neighborhood_name': 'el Clot',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8018,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162417,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132306',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32186E+15',
#   'geo_epgs_25831_y': '4,58433E+14',
#   'geo_epgs_4326_x': '4,14076E+15',
#   'geo_epgs_4326_y': '2,18864E+16',
#   'padro': {'Dones': 13956, 'Homes': 12803, 'Total': 26759}},
#  '\ufeff92086009791': {'register_id': '\ufeff92086009791',
#   'name': 'Mercat del Poblenou',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49295',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349003,
#   'addresses_road_name': 'Pl Unió',
#   'addresses_start_street_number': 25,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 68,
#   'addresses_neighborhood_name': 'el Poblenou',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8005,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161888,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132309',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33582E+16',
#   'geo_epgs_25831_y': '4,58358E+15',
#   'geo_epgs_4326_x': '4,1401E+15',
#   'geo_epgs_4326_y': '2,20543E+16',
#   'padro': {'Dones': 17675, 'Homes': 16736, 'Total': 34411}},
#  '\ufeff92086009793': {'register_id': '\ufeff92086009793',
#   'name': 'Mercat de Provençals',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43597',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208205,
#   'addresses_road_name': 'Carrer de Menorca',
#   'addresses_start_street_number': 19,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 72,
#   'addresses_neighborhood_name': 'Sant Martí de Provençals',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162487,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '662002663',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32853E+15',
#   'geo_epgs_25831_y': '4,58563E+15',
#   'geo_epgs_4326_x': '4,14195E+15',
#   'geo_epgs_4326_y': '2,19649E+16',
#   'padro': {'Dones': 13958, 'Homes': 12271, 'Total': 26229}},
#  '\ufeff92086009774': {'register_id': '\ufeff92086009774',
#   'name': "Mercat de l'Estrella",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44753,5782',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 144306,
#   'addresses_road_name': 'Carrer de Pi i Margall',
#   'addresses_start_street_number': 73,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162002,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132315',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30128E+15',
#   'geo_epgs_25831_y': '4,5846E+15',
#   'geo_epgs_4326_x': '4,14099E+16',
#   'geo_epgs_4326_y': '2,16399E+16',
#   'padro': {'Dones': 19121, 'Homes': 16231, 'Total': 35352}},
#  '\ufeff92086009777': {'register_id': '\ufeff92086009777',
#   'name': "Mercat de Vall d'Hebron -Taxonera",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42722',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 352507,
#   'addresses_road_name': "Pg Vall d'Hebron",
#   'addresses_start_street_number': 130,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 38,
#   'addresses_neighborhood_name': 'la Teixonera',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8035,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162005,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132344',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28343E+16',
#   'geo_epgs_25831_y': '4,58619E+15',
#   'geo_epgs_4326_x': '4,14241E+15',
#   'geo_epgs_4326_y': '2,14245E+15',
#   'padro': {'Dones': 6248, 'Homes': 5796, 'Total': 12044}},
#  '\ufeff92086009778': {'register_id': '\ufeff92086009778',
#   'name': "Mercat d'Horta",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42873',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 329505,
#   'addresses_road_name': 'Carrer del Tajo',
#   'addresses_start_street_number': 75,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 43,
#   'addresses_neighborhood_name': 'Horta',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162391,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '934204858',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29782E+15',
#   'geo_epgs_25831_y': '4,58679E+13',
#   'geo_epgs_4326_x': '4,14296E+15',
#   'geo_epgs_4326_y': '2,15961E+16',
#   'padro': {'Dones': 14918, 'Homes': 13137, 'Total': 28055}},
#  '\ufeff92086009780': {'register_id': '\ufeff92086009780',
#   'name': 'Mercat de La Mercè',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44771,46113',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 119003,
#   'addresses_road_name': 'Passeig de Fabra i Puig',
#   'addresses_start_street_number': 270,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 46,
#   'addresses_neighborhood_name': 'el Turó de la Peira',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8031,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162007,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132340',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30952E+15',
#   'geo_epgs_25831_y': '4,58688E+15',
#   'geo_epgs_4326_x': '4,14305E+16',
#   'geo_epgs_4326_y': '2,1736E+16',
#   'padro': {'Dones': 8609, 'Homes': 7577, 'Total': 16186}},
#  '\ufeff92086009784': {'register_id': '\ufeff92086009784',
#   'name': 'Mercat del Bon Pastor',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49155',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 295709,
#   'addresses_road_name': 'C Sant Adrià',
#   'addresses_start_street_number': 154,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 59,
#   'addresses_neighborhood_name': 'el Bon Pastor',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162011,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132333',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33679E+15',
#   'geo_epgs_25831_y': '4,58746E+15',
#   'geo_epgs_4326_x': '4,1436E+15',
#   'geo_epgs_4326_y': '2,20617E+15',
#   'padro': {'Dones': 6870, 'Homes': 6860, 'Total': 13730}},
#  '\ufeff99400069155': {'register_id': '\ufeff99400069155',
#   'name': 'Mercat del Fort Pienc',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '37958,58828',
#   'modified': '44732,38674',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 701420,
#   'addresses_road_name': 'Pl Fort Pienc',
#   'addresses_start_street_number': 3,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 208673,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132316',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31663E+15',
#   'geo_epgs_25831_y': '4,58302E+15',
#   'geo_epgs_4326_x': '4,13958E+15',
#   'geo_epgs_4326_y': '2,18254E+15',
#   'padro': {'Dones': 17443, 'Homes': 16002, 'Total': 33445}},
#  '\ufeff99400695137': {'register_id': '\ufeff99400695137',
#   'name': 'Mercat de Núria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '44754,5899',
#   'modified': '44760,37418',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 275600,
#   'addresses_road_name': 'Avinguda dels Rasos de Peguera',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': 186.0,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 460429,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132890',
#   'values_outstanding': 'FALSO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '430903145',
#   'geo_epgs_25831_y': '4590148469',
#   'geo_epgs_4326_x': '4,146E+15',
#   'geo_epgs_4326_y': '2,17264E+16',
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}}}

# %%
#Visualizar el diccionario resultante. ¿Cuántos registros tiene? ¿Coincide este valor con el número de instancias del dataframe df_empleos?
#TODO

# %%
# Cuántas mujeres hay en el barrio que está el mercado con register_id=92086009450
#TODO
mercados_dict['\ufeff92086009450']['padro']
# Out:
# {'Dones': 28118, 'Homes': 24046, 'Total': 52164}

# %%
# ¿En qué calle esta el mercado cuyo register_id=﻿92086009457?
#TODO
mercados_dict['\ufeff92086009457']['addresses_road_name']
# Out:
# 'Travessera de les Corts'

# %%
#Guardar el diccionario en un fichero con formato .json.
#TODO
import json
#json_data = json.dumps(mercados_dict)
#json_data
print(mercados_dict.values())
# Out:
# dict_values([{'register_id': '\ufeff92086009449', 'name': 'Mercat de La Concepció', 'institution_id': nan, 'institution_name': nan, 'created': '31044', 'modified': '44732,38445', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 18505, 'addresses_road_name': "Carrer d'Aragó", 'addresses_start_street_number': 311, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 7, 'addresses_neighborhood_name': "la Dreta de l'Eixample", 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8009, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161780, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132314', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 66731068, 'secondary_filters_name': 'WiFi BCN', 'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN", 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,30537E+14', 'geo_epgs_25831_y': '4,583E+15', 'geo_epgs_4326_x': '4,13956E+15', 'geo_epgs_4326_y': '2,16907E+15', 'padro': {'Dones': 23431, 'Homes': 20657, 'Total': 44088}}, {'register_id': '\ufeff92086009450', 'name': 'Mercat de la Sagrada Família', 'institution_id': nan, 'institution_name': nan, 'created': '31044', 'modified': '44728,48622', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 238400, 'addresses_road_name': 'Carrer de Padilla', 'addresses_start_street_number': 255, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 6, 'addresses_neighborhood_name': 'la Sagrada Família', 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8013, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161781, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132324', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 58731068, 'secondary_filters_name': 'Mercats municipals', 'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals', 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,31213E+16', 'geo_epgs_25831_y': '4,58412E+15', 'geo_epgs_4326_x': '4,14057E+15', 'geo_epgs_4326_y': '2,17703E+15', 'padro': {'Dones': 28118, 'Homes': 24046, 'Total': 52164}}, {'register_id': '\ufeff92086009452', 'name': 'Mercat de Sant Antoni', 'institution_id': nan, 'institution_name': nan, 'created': '33049', 'modified': '44768,41858', 'addresses_roadtype_id': nan, 'addresses_roadtype_name': nan, 'addresses_road_id': 349706, 'addresses_road_name': "Carrer del Comte d'Urgell", 'addresses_start_street_number': 1, 'addresses_end_street_number': nan, 'addresses_neighborhood_id': 10, 'addresses_neighborhood_name': 'Sant Antoni', 'addresses_district_id': 2, 'addresses_district_name': 'Eixample', 'addresses_zip_code': 8011, 'addresses_town': 'Barcelona', 'addresses_main_address': 'VERDADERO', 'addresses_type': nan, 'values_id': 161783, 'values_attribute_id': 20001, 'values_category': 'Telèfons', 'values_attribute_name': 'Tel.', 'values_value': '934132300', 'values_outstanding': 'VERDADERO', 'values_description': nan, 'secondary_filters_id': 58731068, 'secondary_filters_name': 'Mercats municipals', 'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals', 'secondary_filters_tree': 651, 'secondary_filters_asia_id': '6,5103E+13', 'geo_epgs_25831_x': '4,29907E+16', 'geo_epgs_25831_y': '4,58123E+15', 'geo_epgs_4326_x': '4,13796E+15', 'geo_epgs_4326_y': '2,16174E+15', 'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}}, {'register_id' ...
